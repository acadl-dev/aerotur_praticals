# %%
from dash import Dash, html, dcc, Input, Output
import plotly.express as px
import pandas as pd

# Carregar os dados
df = pd.read_excel('AHRG - Janeiro 2024.xlsx')

display(df)



# Criar o app
app = Dash(__name__)
# Out:
#                          LOCAL     PEDIDO ATENDIMENTO  \
# 0    1 ANDAR PEDIATRICO-ADULTO  707687-02  02/01/2024
# 1    1 ANDAR PEDIATRICO-ADULTO  707687-02  02/01/2024
# 2    1 ANDAR PEDIATRICO-ADULTO  707687-02  02/01/2024
# 3    1 ANDAR PEDIATRICO-ADULTO  708977-02  07/01/2024
# 4    1 ANDAR PEDIATRICO-ADULTO  708977-02  07/01/2024
# ..                         ...        ...         ...
# 436          UTI PEDIATRICA II  709757-02  10/01/2024
# 437          UTI PEDIATRICA II  709757-02  10/01/2024
# 438          UTI PEDIATRICA II  712233-02  19/01/2024
# 439          UTI PEDIATRICA II  712233-02  19/01/2024
# 440          UTI PEDIATRICA II  712233-02  19/01/2024
#
#                              CLIENTE              IDADE  \
# 0      REMILLY MICKELLY ARAUJO SOUZA  23 anos e 4 meses
# 1      REMILLY MICKELLY ARAUJO SOUZA  23 anos e 4 meses
# 2      REMILLY MICKELLY ARAUJO SOUZA  23 anos e 4 meses
# 3        SARA DE SOUSA COSTA RIBEIRO   4 anos e 6 meses
# ...
